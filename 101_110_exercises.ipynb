# %% [markdown]
# <a href="https://colab.research.google.com/github/Krzesimir13/Data-Science/blob/main/101_110_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas
#
# ### Spis treści:
# * [Import biblioteki](#0)
# * [Ćwiczenie 101](#1)
# * [Ćwiczenie 102](#2)
# * [Ćwiczenie 103](#3)
# * [Ćwiczenie 104](#4)
# * [Ćwiczenie 105](#5)
# * [Ćwiczenie 106](#6)
# * [Ćwiczenie 107](#7)
# * [Ćwiczenie 108](#8)
# * [Ćwiczenie 109](#9)
# * [Ćwiczenie 110](#10)

# %% [markdown]
# ### <a name='0'></a>Import biblioteki

# %%
import numpy as np
import pandas as pd

pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ### <a name='1'></a> Ćwiczenie 101
# Z podanej poniżej listy:
#
#
# ```
# stocks = ['PLW', 'CDR', '11B', 'TEN']
# ```
# Utwórz obiekt typu Series.
#
# __Oczekiwany wynik:__
#
#
# ```
# 0    PLW
# 1    CDR
# 2    11B
# 3    TEN
# dtype: object
# ```

# %%
stocks = ['PLW', 'CDR', '11B', 'TEN']
pd.Series(stocks)
# Out:
# 0    PLW
# 1    CDR
# 2    11B
# 3    TEN
# dtype: object

# %% [markdown]
# ### <a name='2'></a> Ćwiczenie 102
# Z podanego poniżej słownika:
#
#
# ```
# stocks = {'PLW': 387.00, 'CDR': 339.5, 'TEN': 349.5, '11B': 391.0}
# ```
# Utwórz obiekt typu Series i przypisz do zmiennej _quotations_.
#
# __Oczekiwany wynik:__
#
#
# ```
# PLW    387.0
# CDR    339.5
# TEN    349.5
# 11B    391.0
# dtype: float64
# ```

# %%
stocks = {'PLW': 387.00, 'CDR': 339.5, 'TEN': 349.5, '11B': 391.0}
quotations = pd.Series(stocks)
quotations
# Out:
# PLW    387.0
# CDR    339.5
# TEN    349.5
# 11B    391.0
# dtype: float64

# %% [markdown]
# ### <a name='3'></a> Ćwiczenie 103
# Przekształć obiekt _quotations_ do listy.
#
# __Oczekiwany wynik:__
#
#
# ```
# [387.0, 339.5, 349.5, 391.0]
# ```

# %%
quotations.to_list()
# Out:
# [387.0, 339.5, 349.5, 391.0]

# %% [markdown]
# Przekształć obiekt _quotations_ do tablicy _numpy_.

# %%
quotations.to_numpy()
# Out:
# array([387. , 339.5, 349.5, 391. ])

# %% [markdown]
# ### <a name='4'></a> Ćwiczenie 104
# Przekształć obiekt _quotations_ do obiektu _DataFrame_. Ustaw nazwę kolumny na _price_.

# %%
pd.DataFrame(quotations, columns=['price'])
# Out:
#      price
# PLW  387.0
# CDR  339.5
# TEN  349.5
# 11B  391.0

# %% [markdown]
# ### <a name='5'></a> Ćwiczenie 105
# Wykorzystując bibliotekę _numpy_ zbuduj poniższy obiekt typu _Series_:
#
#
# ```
# 101    10.0
# 102    20.0
# 103    30.0
# 104    40.0
# 105    50.0
# 106    60.0
# 107    70.0
# 108    80.0
# 109    90.0
# dtype: float64
# ```

# %%
index = np.arange(start=101, stop=110, step=1)
data = np.arange(start=10.0, stop=100.0, step=10.0)
pd.Series(data, index=index)
# Out:
# 101    10.0
# 102    20.0
# 103    30.0
# 104    40.0
# 105    50.0
# 106    60.0
# 107    70.0
# 108    80.0
# 109    90.0
# dtype: float64

# %% [markdown]
# ### <a name='6'></a> Ćwiczenie 106
# Podany jest poniższy obiekt typu _Series_:
#
# ```
# series = pd.Series(['001', '002', '003', '004'], list('abcd'))
# ```
# Skonwertuj typ obiektu _series_ na _int_.

# %%
series = pd.Series(['001', '002', '003', '004'], list('abcd'))
series.astype(int)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# Skonwertuj typ obiektu _series_ na _float_.

# %%
series.astype(float)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %% [markdown]
# ### <a name='7'></a> Ćwiczenie 107
# Do poniższego obiektu _quotations_:
#
# ```
# stocks = {'PLW': 387.00, 'CDR': 339.5, 'TEN': 349.5, '11B': 391.0}
# quotations = pd.Series(data=stocks)
# ```
# Dodaj dwa elementy:
# * indeks: BBT, wartość: 25.5
# * indeks: F51, wartość: 19.2
#
# __Oczekiwany wynik:__
#
#
# ```
# PLW    387.0
# CDR    339.5
# TEN    349.5
# 11B    391.0
# BBT     25.5
# F51     19.2
# dtype: float64
# ```

# %%
stocks = {'PLW': 387.00, 'CDR': 339.5, 'TEN': 349.5, '11B': 391.0}
quotations = pd.Series(data=stocks)
quotations['BBT'] = 25.5
quotations['F51'] = 19.2
quotations
# Out:
# PLW    387.0
# CDR    339.5
# TEN    349.5
# 11B    391.0
# BBT     25.5
# F51     19.2
# dtype: float64

# %% [markdown]
# ### <a name='8'></a> Ćwiczenie 108
# Obiekt _quotations_ z poprzedniego ćwiczenia przekształć do obiektu typu _DataFrame_. Zresetuj indeks i nadaj nazwy kolumn '_ticker_' oraz _'price'_.

# %%
quotations.to_frame().reset_index().rename(columns={'index' : 'ticker', 0 : 'price'})
# Out:
#   ticker  price
# 0    PLW  387.0
# 1    CDR  339.5
# 2    TEN  349.5
# 3    11B  391.0
# 4    BBT   25.5
# 5    F51   19.2

# %% [markdown]
# ### <a name='9'></a> Ćwiczenie 109
# Zbuduj poniższy obiekt _DataFrame_ i przypisz do zmiennej _companies_:
#
# |    | company   |   price | ticker   |
# |---:|:----------|--------:|:---------|
# |  0 | Amazon    |  2375   | AMZN.US  |
# |  1 | Microsoft |   178.6 | MSFT.US  |
# |  2 | Facebook  |   179.2 | FB.US    |

# %%
companies = pd.DataFrame([['Amazon', 2375, 'AMZN.US'],
                        ['Microsoft', 178.6, 'MSFT.US'],
                         ['Facebook', 179.2, 'FB.US']],
                         columns=['company', 'price', 'ticker'])
companies
# Out:
#      company   price   ticker
# 0     Amazon  2375.0  AMZN.US
# 1  Microsoft   178.6  MSFT.US
# 2   Facebook   179.2    FB.US

# %% [markdown]
# ### <a name='10'></a> Ćwiczenie 110
# Przekształć pierwszą kolumnę obiektu _companies_ w indeks.

# %%
companies = companies.set_index('company')
companies
# Out:
#             price   ticker
# company
# Amazon     2375.0  AMZN.US
# Microsoft   178.6  MSFT.US
# Facebook    179.2    FB.US

# %% [markdown]
# Wytnij wiersz dla spółki _Facebook_ z obiektu _companies_.

# %%
companies.loc['Facebook']
# Out:
# price     179.2
# ticker    FB.US
# Name: Facebook, dtype: object

# %% [markdown]
# Wytnij cenę dla spółki _Microsoft_

# %%
companies.loc['Microsoft', 'price']
# Out:
# np.float64(178.6)
